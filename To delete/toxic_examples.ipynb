# %%
import pandas as pd
import numpy as np
from detoxify import Detoxify

classifier = Detoxify('unbiased')
Examples = ['the monkey makes jokes', 'the mean monkey makes means jokes about means', 'the annoying monkey makes annoying jokes about means',
'The malevolent monkey makes malevolent jokes about means', 
'The nasty monkey makes nasty jokes about means', 'The despicable monkey makes despicable jokes about means', 
'The bastard monkey makes bastard jokes about means']
results = pd.DataFrame(classifier.predict(Examples))
results['Comments'] = Examples
results = results[['Comments', 'toxicity',  'severe_toxicity', 'obscene', 'identity_attack', 'insult', 'threat', 'sexual_explicit']]
results
# Out:
#                                             Comments  toxicity  \
# 0                             the monkey makes jokes  0.105275
# 1      the mean monkey makes means jokes about means  0.169568
# 2  the annoying monkey makes annoying jokes about...  0.213984
# 3  The malevolent monkey makes malevolent jokes a...  0.462586
# 4     The nasty monkey makes nasty jokes about means  0.615834
# 5  The despicable monkey makes despicable jokes a...  0.707401
# 6  The bastard monkey makes bastard jokes about m...  0.995640
#
#    severe_toxicity   obscene  identity_attack    insult    threat  \
# 0         0.000014  0.000717         0.001989  0.063598  0.000312
# 1         0.000014  0.000817         0.002283  0.131922  0.000228
# 2         0.000019  0.001182         0.002251  0.153144  0.000299
# 3         0.000031  0.001146         0.003987  0.397109  0.000386
# 4         0.000024  0.000813         0.002809  0.556884  0.000381
# 5         0.000016  0.000449         0.001647  0.657305  0.000226
# 6         0.032880  0.883254         0.030733  0.975668  0.000906
#
#    sexual_explicit
# 0         0.000522
# 1         0.000401
# 2         0.000682
# 3         0.000831
# 4         0.000466
# 5         0.000282
# 6         0.028742
